# %% [markdown]
# # Retrieval Augmented Generation (RAG) 애플리케이션 구축: Part 2 - Chatbot Agent
#
# ### 사용자와의 상호작용을 기억하는 메모리 기능과 다단계 검색(multi-step retrieval)을 통합한 RAG 애플리케이션을 구축
#
# - **Part 1**: RAG 개념을 소개하고, 최소한의 구현 방법을 설명합니다.
# - **Part 2** 기존 구현을 확장하여 대화형 상호작용과 다단계 검색 프로세스를 처리할 수 있도록 개선합니다.
#
# 여기서는 **과거 대화 기록을 현재 답변 논리에 통합하는 방법**을 중점적으로 다룹니다.
#
# **두 가지 접근 방식**을 다룹니다.
#
# 1. **체인(Chains)**   - 한 번의 검색 단계만 실행합니다.
#
# 2. **에이전트(Agents)**   - LLM이 필요에 따라 **여러 번의 검색 단계 (다중 단계 검색)** 를 수행하도록 자유롭게 설정합니다.

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model
from langchain_openai import OpenAIEmbeddings

model = init_chat_model("gpt-5-nano", model_provider="openai")
# model = init_chat_model("gemini-2.5-flash", model_provider="google_genai")

# 사용할 임베딩 모델의 이름을 지정
embeddings = OpenAIEmbeddings(model='text-embedding-3-large')

# %%
from langchain_core.vectorstores import InMemoryVectorStore

vector_store = InMemoryVectorStore(embeddings)

# %% [markdown]
# ### **문서 불러오기 (Loading Documents)**
#
# 우리가 콘텐츠를 불러올 웹사이트는 **[Harheem의 "LLM Agents" 블로그 게시물](https://harheem.github.io/llm/2024/02/28/llm-agents.html)** 이며, 이를 통해 해당 게시물의 내용에 대한 질문에 답할 수 있도록 할 것입니다.

# %%
import bs4
from langchain_community.document_loaders import WebBaseLoader

# 주요 콘텐츠 태그만 필터링 (제목, 본문, 코드 등)
bs4_strainer = bs4.SoupStrainer(name=("h1", "h2", "h3", "p", "pre", "li"))

# WebBaseLoader 사용: requests_kwargs로 User-Agent 설정
loader = WebBaseLoader(
    web_paths=("https://botpress.com/ko/blog/llm-agents",),
    bs_kwargs={"parse_only": bs4_strainer},
    requests_kwargs={
        "headers": {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
        }
    }
)

# 문서 로드
docs = loader.load()

# 결과 확인
assert len(docs) == 1
print(f"Total characters: {len(docs[0].page_content)}")

from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,            # 각 청크의 최대 문자 수 (1,000자)
    chunk_overlap=200,          # 청크 간 겹치는 문자 수 (200자)
    add_start_index=True,       # 원본 문서에서 각 청크의 시작 인덱스를 추적
)

# 불러온 문서를 설정한 기준에 따라 청크로 분할
all_splits = text_splitter.split_documents(docs)

# 분할된 청크(서브 문서)의 개수 출력
print(f"블로그 글을 {len(all_splits)}개의 하위 문서로 분할했습니다.")

_ = vector_store.add_documents(documents=all_splits)
# Out:
# Total characters: 8582
# 블로그 글을 11개의 하위 문서로 분할했습니다.

# %% [markdown]
# ### LangChain 고유 방식 : Part 1 에서 사용했던 상태(state) 기반 접근법
# - LangChain의 **RAG 애플리케이션**에서는 사용자 입력, 검색된 문서, 그리고 생성된 답변을 각각 상태(state)라는 구조 안에 별도의 키(key)로 저장했습니다.
# - 예를 들면:
#
# ```python
#    # 애플리케이션의 상태(State) 객체 정의
#     class State(TypedDict):
#         question: str          # 사용자 질문을 저장하는 문자열 필드
#         context: List[Document]    # 검색된 문서 목록을 저장하는 필드
#         answer: str           # 생성된 답변을 저장하는 문자열 필드
#
#     state = {
#        "question": "고양이는 몇 살까지 살아요?",
#        "context": ["고양이의 평균 수명은 12-18년입니다."],
#        "answer": "고양이는 보통 12-18년 정도 삽니다."
#      }
# ```
# - 하지만 이런 방식은 챗봇의 경우 대화의 흐름을 자연스럽게 표현하기 어려울 수 있으므로 v0.3 부터는 OpenAI 의 메시지 형식을 활용하여 다음과 같은 방식을 권장합니다.
#
# ---
#
# ### 새로운 메시지(messages) 기반 시퀀스 접근법 - OpenAI API 방식
#
# - 여기에는 다음과 같은 요소들이 포함됩니다:
#    1. **사용자 메시지(User Message):** HumanMessage 로 표현
#    2. **어시스턴트 메시지(Assistant Message):** AIMessage 로 표현
#    3. **도구 메시지(Tool Message):** 검색된 문서나 기타 참고 자료 - ToolMessage로 표현
#    4. **최종 응답**: AIMessage 로 표현
#
#
# ```python
#     from langgraph.graph import MessagesState
#
#     def query_or_respond(state: MessagesState):
#
#         response = [
#             {"role": "user", "content": "고양이는 몇 살까지 살아요?"},
#             {"role": "tool", "content": "검색 결과: 고양이의 평균 수명은 12-18년입니다."},
#             {"role": "assistant", "content": "고양이는 보통 12-18년 정도 삽니다."}
#         ]
#
#         ..................
#
#         return {"messages": [response]}
# ```
# ---

# %% [markdown]
# 이 메시지 기반 시퀀스 모델 사용 편의를 위해, LangGraph에서는 내장된 MessagesState 버전을 제공합니다.

# %%
from langgraph.graph import MessagesState, StateGraph

graph_builder = StateGraph(MessagesState)

# %% [markdown]
# **도구 호출(tool-calling)** 을 활용해 검색 단계와 상호작용하는 것에는 또 다른 이점이 있습니다. 바로 **검색에 사용할 쿼리를 모델이 직접 생성할 수 있다는 점**입니다.
#
# 이것은 특히 **대화형 환경(conversational setting)** 에서 중요합니다. 사용자의 질문이 **대화 이력(chat history)** 을 기반으로 문맥화되어야 할 수 있기 때문입니다.
#
# 이 기능 역시 OpenAI API 의 tool calling 기능을 LangChain에서 활용하는 사례입니다.
#
# ---
#
# ### **예시 대화**
#
# > **Human:** "Task Decomposition이란 무엇인가요?"
# > **AI:** "Task Decomposition은 복잡한 작업을 더 작고 단순한 단계로 나누어, 에이전트나 모델이 더 쉽게 관리할 수 있도록 만드는 과정입니다."
# > **Human:** "일반적으로 Task Decomposition을 수행하는 방법에는 어떤 것들이 있나요?"
#
# - 이 시나리오에서 모델은 `"Task Decomposition의 일반적인 접근법"`과 같은 검색 쿼리를 생성할 수 있습니다.
# - **도구 호출(tool-calling)** 은 이런 과정을 자연스럽게 지원합니다.
#
# ---
#
# 이제 검색 단계를 **도구(tool)** 로 전환해 보겠습니다.  `@tool` 함수는 다음과 같이 `OpenAI의 function-calling` 구조로 함수들을 선언합니다.
# ```
# {
#   "name": "retrieve",
#   "description": "문서를 검색합니다",
#   "parameters": {
#     "type": "object",
#     "properties": {
#       "query": { "type": "string", "description": "검색할 쿼리" }
#     },
#     "required": ["query"]
#   }
# }
# ```

# %%
from langchain_core.tools import tool

# 검색(retrieve) 함수를 도구로 정의
# - response_format="content_and_artifact"로 지정하면 
# 반드시 결과를 직렬화된 content와 artifact로 반환 - Langchain이 format check
@tool(response_format="content_and_artifact")
def retrieve(query: str):
    """
    주어진 쿼리와 관련된 정보를 검색합니다. 
    query: 검색할 텍스트 쿼리입니다. llm 이 생성해 줍니다.
    """    
    # 벡터 스토어에서 유사도 검색 수행. 가장 유사한 두 개의 문서를 반환.
    retrieved_docs = vector_store.similarity_search(query)
    
    # 검색된 문서를 문자열로 직렬화
    serialized = "\n\n".join(
        (f"Source: {doc.metadata}\n" f"Content {doc.page_content}")
        for doc in retrieved_docs
    )
    
    # 직렬화된 결과(content)와 원본 문서 목록(artifact) 반환.
    return serialized, retrieved_docs

# %% [markdown]
# 우리의 그래프는 세 개의 노드로 구성됩니다:
#
# 1. **사용자 입력을 처리하는 노드** - 검색을 위한 쿼리를 생성하거나, 직접 응답을 생성하는 역할을 합니다.
#
# 2. **검색(retrieval) 도구를 실행하는 노드** - 검색 단계를 수행하여 관련 문서를 가져오는 역할을 합니다.
#
# 3. **최종 응답을 생성하는 노드** - 검색된 문맥(context)을 활용하여 최종 답변을 생성합니다.
#
# 아래에서 이 노드들을 구축하겠습니다.
# 특히, **LangGraph의 사전 구축된 구성 요소 중 하나인 `ToolNode`를 활용**할 것입니다.
# 이 `ToolNode`는 도구를 실행하고, 그 결과를 **`ToolMessage` 형태로 상태(state)에 추가**하는 역할을 합니다.

# %%
from langchain_core.messages import SystemMessage
from langgraph.prebuilt import ToolNode

# 단계 1: 도구 호출을 포함할 수 있는 AIMessage를 생성하여 전송합니다.
# MessagesState는 메시지를 덮어쓰지 않고 상태에 추가합니다.
def query_or_respond(state: MessagesState):
    """검색을 위한 도구 호출을 생성하거나 응답을 생성합니다."""
    llm_with_tools = model.bind_tools([retrieve])
    response = llm_with_tools.invoke(state["messages"])
    return {"messages": [response]}

# 단계 2: 검색을 실행합니다. (검색에 필요한 argument는 llm이 생성)
tools = ToolNode([retrieve])

# 단계 3: 검색된 내용을 사용하여 응답을 생성합니다. 
# (검색된 내용을 다시 llm에게 전달)
def generate(state: MessagesState):
    """답변을 생성합니다."""
    # 최근 생성된 ToolMessages 가져오기
    recent_tool_messages = []
    for message in reversed(state["messages"]):
        if message.type == "tool":
            recent_tool_messages.append(message)
        else:
            break
    tool_messages = recent_tool_messages[::-1]

    # 프롬프트 형식으로 변환
    docs_content = "\n\n".join(doc.content for doc in tool_messages)
    system_message_content = (
        "당신은 질문-응답 작업을 위한 어시스턴트입니다. "
        "주어진 검색 결과만 이용해서 질문에 답하세요. "
        "\n\n"
        f"{docs_content}"
    )
    conversation_messages = [
        message
        for message in state["messages"]
        if message.type in ("human", "system")
        or (message.type == "ai" and not message.tool_calls)
    ]
    prompt = [SystemMessage(system_message_content)] + conversation_messages

    # 실행
    response = model.invoke(prompt)
    return {"messages": [response]}

# %% [markdown]
# 마지막으로, 우리의 애플리케이션을 단일 그래프 객체로 컴파일합니다.
#
# 첫 번째 `query_or_respond` 단계가 "쇼트 서킷(어떤 조건이 충족되어 스킵)" 되어 도구 호출을 생성하지 않는 경우, 사용자에게 직접 응답할 수 있도록 허용합니다. 이를 통해 검색 단계가 필요하지 않은 일반적인 인사와 같은 대화 경험을 지원할 수 있습니다.

# %%
from langgraph.graph import START, END
from langgraph.prebuilt import ToolNode, tools_condition
from langgraph.graph import MessagesState, StateGraph

graph_builder = StateGraph(MessagesState)

# 그래프 빌더에 각 노드 추가
graph_builder.add_node(query_or_respond)  # 쿼리 생성 또는 응답 노드 추가
graph_builder.add_node(tools)  # 검색(도구 호출) 노드 추가
graph_builder.add_node(generate)  # 최종 응답 생성 노드 추가

# 그래프의 시작점을 설정
# graph_builder.set_entry_point("query_or_respond")
graph_builder.add_edge(START, "query_or_respond")

# 조건부 엣지(경로) 설정
graph_builder.add_conditional_edges(
    "query_or_respond",  # 첫 번째 노드: query_or_respond
    tools_condition,  # 조건 함수: 도구 호출이 필요한지 여부를 판단
    {END: END, "tools": "tools"},  # 조건에 따라 실행 경로 결정
    # - END: 도구 호출이 필요하지 않으면 실행 종료
    # - "tools": 검색이 필요하면 tools 노드로 이동
)

# 그래프 엣지(경로) 설정
graph_builder.add_edge("tools", "generate")  # 도구 검색 후 응답 생성 단계로 이동
graph_builder.add_edge("generate", END)  # 응답 생성 후 실행 종료

# 그래프 컴파일 및 출력
graph = graph_builder.compile()
graph

# %% [markdown]
# 우리의 애플리케이션을 테스트해 봅시다.
#
# 추가적인 검색 단계가 필요하지 않은 메시지에 적절하게 응답하는 것을 확인할 수 있습니다.

# %%
input_message = "안녕! 난 길동이야."

for step in graph.stream(
    {"messages": [{"role": "user", "content": input_message}]},
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# 안녕! 난 길동이야.
# ================================== Ai Message ==================================
#
# 안녕, 길동아! 반가워. 오늘은 어떤 걸 도와줄까? 질문이 있으면 바로 물어봐도 되고, 글 다듬기나 번역, 정보 찾기, 공부 도움 등 필요하면 말해줘.

# %% [markdown]
# 그리고 검색을 실행할 때, 쿼리 생성, 검색, 그리고 응답 생성 단계를 스트리밍하여 관찰할 수 있습니다.

# %%
input_message = "LLM 에이전트 프레임워크를 구성하는 핵심 구성 요소는 무엇인가요?"

for step in graph.stream(
    {"messages": [{"role": "user", "content": input_message}]},
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# LLM 에이전트 프레임워크를 구성하는 핵심 구성 요소는 무엇인가요?
# ================================== Ai Message ==================================
#
# 다음은 LLM 에이전트 프레임워크를 구성하는 핵심 구성 요소들입니다. 구현에 따라 용어가 다를 수 있지만, 대체로 이 정도의 모듈로 구성됩니다.
#
# - LLM 엔진 및 프롬팅 layer
#   - 모델 선택, 프롬프트 템플릿, 컨텍스트 관리 등을 담당합니다. Retrieval-Augmented Generation(RAG)나 체인 오브 thought 등 프롬팅 전략이 포함될 수 있습니다.
#
# - 추론/계획 모듈
#   - 입력의 목표를 해석하고 문제를 분해해 작업 계획을 수립합니다. 어떤 도구를 사용할지, 어떤 순서로 실행할지 결정하는 정책(또는 의사결정 로직)을 포함합니다.
#
# - 도구(툴) 카탈로그 및 플러그인 관리
#   - 에이전트가 사용할 수 있는 API/플러그인 목록과 어댑터를 관리합니다. 도구 선택 정책, 인증, 속도 제한, 실패 처리도 이 모듈에서 다룹니다.
#
# - 실행 엔진(액션 런타임)
#   - 도구 호출을 실제로 수행하고, 결과를 받아 후속 처리(파싱, 요약, 재질의화 등)를 수행합니다. 동시성, 에러 재시도, 롤백 등을 포함합니다.
#
# - 메모리 및 상태 관리
#   - 단기 워크스페이스(현재 대화 맥락), 장기 메모리(지식/경험 저장소), 컨텍스트 인덱싱 및 검색 등 대화의 맥락을 관리합니다.
#
# - 컨텍스트 관리 및 사용자 모델링
#   - 사용자 선호, 역할, 대화의 목적, 프라이버시 정책 등을 반영한 개인화된 컨텍스트를 관리합니다.
#
# - 지식 베이스 및 데이터 통합
#   - 외부 데이터 소스, 데이터베이스, 검색 엔진 등을 연결하고 필요한 정보를 실시간으로 불러옵니다. 인덱싱/캐시 관리도 포함될 수 있습니다.
#
# - 안전성, 거버넌스 및 프라이버시
#   - 정책 적용, 콘텐츠 필터링, 위험 평가, 감사 로그, 데이터 보안과 프라이버시 보호 등 준수 영역을 다룹니다.
#
# - 관찰성(모니터링) 및 신뢰성
#   - 로깅, metrics, 트레이싱, 모니터링 대시보드, 에러 알림 등 운영 가시성을 제공합니다.
#
# - 학습 및 개선 루프
#   - 사용자 피드백, 시스템성능 피드백 등을 통해 프롬프트 최적화, 모델 개선(예: RLHF, 프롬프트 튜닝), 도구 사용 정책을 업데이트합니다.
#
# - 배포 및 인프라
#   - 실행 환경(컨테이너/서버리스), API 게이트웨이, 마이크로서비스 간 연결, 확장성, 보안 설정 등을 포함합니다.
#
# - 사용자 인터페이스(Human-in-the-loop 가능 영역)
#   - 필요 시 사람의 승인이나 개입이 필요한 흐름을 위한 UI/UX, 대시보드, 피드백 창구를 제공합니다.
#
# 간단한 워크플로 예시
# - 사용자가 입력 → 컨텍스트 업데이트 → LLM 프롬트 생성 → 계획 모듈이 도구 선택 → 실행 엔진이 도구 호출 → 도구 응답 처리 및 필요시 추가 처리 → 최종 응답 생성 및 사용자에 반환 → 메모리 업데이트 및 피드백 수집.
#
# 원하는 용도에 따라 위 구성 요소 중 일부를 결합하거나 제거할 수 있습니다. 예를 들어 리액티브한 대화 에이전트만 원한다면 계획/도구 사용의 복잡도를 낮추고, 강력한 자동화가 필요하면 플러그인 카탈로그와 자동 학습 루프를 강조하는 식으로 설계할 수 있습니다.

# %%
input_message = "LLM 에이전트 프레임워크를 구성하는 핵심 구성 요소는 무엇인가요?"

for step in graph.stream(
    {"messages": [{"role": "user", "content": input_message}]},
    stream_mode="updates",
):
    # 어떤 노드에서 나온 결과인지 확인
    for node_name, delta in step.items():
        print(f"[{node_name} 단계] 결과:")
        print(delta)   # delta 안에는 context 또는 answer가 들어있음
# Out:
# [query_or_respond 단계] 결과:
# {'messages': [AIMessage(content='다음은 LLM 에이전트 프레임워크를 구성하는 대표적이고 핵심적인 구성 요소들입니다. 실제 구현은 목적과 환경에 따라 달라지지만, 이 정도의 구성 요소가 보편적으로 필요합니다.\n\n1) 목표 정의 및 관리(Goals & Constraints)\n- 에이전트가 달성하고자 하는 목표, 제약 조건, 우선순위 등을 명시합니다.\n- 예: 작업 목표, 시간 제약, 리소스 한도, 안전 규칙.\n\n2) 의사결정/계획 엔진(Planner/Reasoner)\n- 목표를 달성하기 위한 계획을 생성하고, 단계별 행동을 구성합니다.\n- 재귀적 분해, 도구 사용 순서 결정, 예외 상황 대처를 포함합니다.\n- 대표 패턴: ReAct류(Reasoning + Action) 흐름, 계획 기반 생성.\n\n3) 추론 및 메타추론 모듈(Reasoning / Reflection)\n- 주어진 상황에서 올바른 판단을 내리기 위한 추론과, 필요하면 자기 반성(피드백으로 계획 수정)을 수행합니다.\n- 특히 복잡한 작업에서 오류를 발견하고 수정하는 역할을 합니다.\n\n4) 관측 및 상태 관리(Observations & State)\n- 에이전트가 환경으로부터 얻은 정보(재확인된 결과, 에러 메시지, 도구 응답 등)와 내부 상태를 저장합니다.\n- 상태에는 현재 목표, 진행 단계, 필요한 데이터 등이 포함됩니다.\n\n5) 기억과 맥락 관리(Memory & Context)\n- 단기 메모리(현재 대화나 세션 맥락)와 장기 메모리(지식 베이스, 사례 기록)로 구성될 수 있습니다.\n- 벡터 저장소를 통한 정보 검색 및 재활용도 포함합니다.\n\n6) 도구/액션 인터페이스(Tools & Actions) 및 실행기(Executor)\n- 외부 시스템(API), 파일 시스템, 코드 실행, 검색 등 에이전트가 사용할 실제 기능들을 추상화한 도구들.\n- 각 도구에 대한 래퍼, 인증, 속도 제한, 샌드박스 실행 등을 포함합니다.\n- 실행기 컴포넌트는 선택한 도구를 실제로 호출하고 결과를 수집합니다.\n\n7) 도구 관리 및 라우팅(Toolkit & Orchestration)\n- 사용 가능한 도구의 카탈로그 관리, 도구 선택 규칙, 권한 관리, 우선순위 정책.\n- 동적 도구 추가/제거, 호출 실패 시 대체 경로 선택 등 운영 이슈를 다룹니다.\n\n8) 대화 관리 및 인터페이스(User Interface / API)\n- 사용자와의 상호작용 방식(API 엔드포인트, 채팅 UI, 음성 인터페이스 등)과 대화 흐름 관리.\n- 다중 에이전트 협업 시 의사소통 채널도 포함합니다.\n\n9) 안전성/거버넌스(Safety & Governance)\n- 정책 기반 제약, 콘텐츠 필터링, 민감 정보 보호, 위험 평가, 실패 시 안전한 종료(손실 없는 중단) 등\n- 윤리적·법적 준수와 롤백 메커니즘도 이 영역에 포함됩니다.\n\n10) 데이터 관리(Data Management)\n- 데이터 모델링, 프라이버시/보안, 데이터 품질 관리, 프로벤ance(추적성) 보장.\n- 입력/출력 데이터의 포맷 표준화와 저장소 관리.\n\n11) 관찰성 및 운영 모니터링(Observability & Telemetry)\n- 로그, 메트릭, 트레이싱, 에러 알림 등을 통해 시스템 상태를 모니터링하고 문제를 디버깅합니다.\n- 성능 지표와 사용 패턴 분석으로 지속 개선에 활용합니다.\n\n12) 실행 루프 및 제어 흐름(Execution Loop / Control Flow)\n- 관찰(Observe) -> 판단(Decide) -> 실행(Act) -> 결과 관찰(Observe) 의 순환 구조를 기본 실행 루프로 사용합니다.\n- 루프에서 실패 시 재시도, 대체 계획, 사용자 확인 요청 등을 처리합니다.\n\n13) 확장성/플러그인 아키텍처(Modularity & Plugins)\n- 새로운 도구, 도메인 지식, 외부 서비스 등을 쉽게 추가할 수 있도록 모듈화된 구조.\n- 의존성 관리 및 버전 관리도 포함합니다.\n\n선호하는 설계 패턴 예시\n- ReAct(Reasoning + Action): LLM이 먼저 이유를 제시하고 도구를 호출하는 순차적 흐름.\n- Plan-and-Execute: 먼저 큰 계획을 세운 뒤 단계별로 실행하고 필요 시 재계획.\n- 기억 중심의 Retrieval-Augmented Generation(RAG): 필요한 정보를 벡터 저장소에서 검색하여 활용.\n\n간단한 실행 예시 흐름\n- 사용자의 목표를 받아 Goal 관리에 저장\n- Planner가 단계별 Action 목록을 생성\n- Executor가 선택된 도구를 호출하고 결과를 반환\n- Observations가 피드백을 제공하고 Memory가 상태를 갱신\n- 필요 시 Safety 모듈이 제약 준수 여부를 확인하고, 실패 시 재계획 수행\n\n필요한 경우 프레임워크의 특정 부분에 대해 예시 아키텍처 다이어그램이나 구현 목록(데이터 모델, API 계약, 인터페이스 스펙)도 함께 도와드릴 수 있습니다. 어떤 도메인이나 사용 사례를 염두에 두고 계신가요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2488, 'prompt_tokens': 174, 'total_tokens': 2662, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1280, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CJqBoHBXnk4VKDqQtvtg2jZGQHSEG', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--a52e3fa3-3bf3-4a3d-8ed9-f1efeb57e5cc-0', usage_metadata={'input_tokens': 174, 'output_tokens': 2488, 'total_tokens': 2662, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1280}})]}

# %% [markdown]
# ### **에이전트(Agents) 방식**
#
# LangGraph의 **사전 구축된 ReAct 에이전트 생성자**를 사용하면, 이를 단 한 줄의 코드로 구현할 수 있습니다.

# %%
import requests

# 곱하기 도구
@tool
def multiply(x: float, y: float) -> float:
    """
    x 와 y 를 곱한다.
    """
    print("** multiply 함수 실행 **", x, y)
    return x * y

# 현재의 온도 가져오기
@tool
def get_weather(latitude, longitude):
    """
    주어진 위도(latitude)와 경도(longitude)를 기반으로 현재 기온(2m 온도)을 조회합니다.
    
    이 함수는 Open-Meteo API를 사용하여 실시간 기상 데이터를 가져오며,
    반환값은 현재 기온(섭씨)입니다.
    
    매개변수:
        latitude (float): 조회할 위치의 위도
        longitude (float): 조회할 위치의 경도
    
    반환값:
        float: 현재 2m 높이에서의 기온 (섭씨)
    """
    response = requests.get(f"https://api.open-meteo.com/v1/forecast?latitude={latitude}&longitude={longitude}&current=temperature_2m")
    data = response.json()
    return data['current']['temperature_2m']

# # 서울의 위도, 경도
# get_weather(37.56667, 126.97806)

# %%
from langgraph.prebuilt import create_react_agent
from langgraph.checkpoint.memory import MemorySaver

# MemorySaver: 워크플로우의 상태를 메모리에 저장
memory = MemorySaver()

tools = [retrieve, get_weather, multiply]

agent_executor = create_react_agent(model, tools, checkpointer=memory)
agent_executor

# %% [markdown]
# 보통 여러 번의 검색 단계가 필요한 질문을 구성하여 확인해 보겠습니다.

# %%
config = {"configurable": {"thread_id": "def1234"}}  

input_message = (
    "LLM 에이전트 프레임워크의 핵심 구성 요소는 무엇인가요?\n\n"
    "서울의 지금 날씨에 20을 곱하면 숫자가 몇인지도 추가로 알려주세요."
    "주어진 도구를 사용하여 답변하세요."
)  
# 사용자 입력 메시지 정의. 첫 번째 질문은 작업 분해의 표준 방법을 묻고,  
# 이후 해당 방법의 실제 수행 방식까지 조사하도록 요청.
for event in agent_executor.stream(
    {"messages": [{"role": "user", "content": input_message}]},  
    # 사용자 메시지를 포함한 입력을 에이전트 실행자(agent_executor)에 전달
    stream_mode="values",  # 각 단계의 전체 state 반환
    config=config,  # 설정 적용
):
    event["messages"][-1].pretty_print()  # 마지막 응답 메시지를 출력
# Out:
# ================================ Human Message =================================
#
# LLM 에이전트 프레임워크의 핵심 구성 요소는 무엇인가요?
#
# 서울의 지금 날씨에 20을 곱하면 숫자가 몇인지도 추가로 알려주세요.주어진 도구를 사용하여 답변하세요.
# ================================== Ai Message ==================================
# Tool Calls:
#   get_weather (call_yaP9WZ7TdQ1YE0gv2QpLry5b)
#  Call ID: call_yaP9WZ7TdQ1YE0gv2QpLry5b
#   Args:
#     latitude: 37.5665
#     longitude: 126.978
# ================================= Tool Message =================================
# Name: get_weather
#
# 15.9
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (call_E7TAYtYRWJzcoU9ySlFHLFpd)
#  Call ID: call_E7TAYtYRWJzcoU9ySlFHLFpd
#   Args:
#     x: 15.9
#     y: 20
# ** multiply 함수 실행 ** 15.9 20.0
# ================================= Tool Message =================================
# Name: multiply
#
# 318.0
# ================================== Ai Message ==================================
#
# 다음 두 가지를 알려드립니다.
#
# - 현재 서울의 기온: 약 15.9°C
# - 15.9에 20을 곱하면: 318.0
#
# LLM 에이전트 프레임워크의 핵심 구성 요소(일반적으로 공통적으로 쓰이는 구조)
#
# - LLM 기반 정책/추론 엔진
#   - 의사결정의 핵심(무엇을 해야 하는지, 어떤 도구를 사용할지 판단)
#   - 자연어로 이유를 설명하거나 자기 점검하는 기능 포함 가능
#
# - 계획자(Planner) 및 의도 분해
#   - 목표를 작은 작업(Task)으로 분해하고 순서를 구성
#   - 멀티스텝 문제를 해결하기 위한 로드맵 생성
#
# - 실행 엔진(Execution / Orchestrator)
#   - 계획을 실제 행동으로 실행하고, 도구 호출을 관리
#   - 동시 실행과 순차 실행 간의 조정, 실패 시 재시도 로직 포함
#
# - 도구 인터페이스/어댑터(Tools & Adapters)
#   - 외부 API, 데이터베이스, 파일 시스템 등과의 연결
#   - 도구의 형식 표준화(입출력 계약, 인증, 속도/오류 처리)
#
# - 메모리 및 상태 관리(Memory & Context)
#   - 짧은 기간의 컨텍스트 유지(최근 대화, 현 상태)
#   - 장기 기억 외부화(지식 베이스, 컨텍스트 창고) 및 검색
#
# - 상태 추적 및 시계열 관리
#   - 과거 대화·결정 내역을 기록하고 재사용
#   - 변경된 상태를 일관되게 반영
#
# - 정책 계층 및 안전장치(Policy & Safety)
#   - 사용 권한, 보안, 프라이버시, 제약 준수
#   - 실수 가능성 최소화, 필요 시 차단/수정 로직
#
# - 에러 처리 및 로깅(Observability & Debugging)
#   - 실행 로그, 모니터링, 트레이싱
#   - 문제 원인 분석 및 성능 개선 피드백 루프
#
# - 인터페이스 계층(Interface Layer)
#   - 사용자 채널(챗, 음성, API)과의 연결
#   - 입력 전처리/출력 포맷 변환
#
# - 데이터 관리 및 지식 관리(Data & Knowledge)
#   - 외부 지식베이스와의 연계, 문맥 상식 보강
#   - 도메인 특화 지식의 인덱싱 및 검색
#
# - 학습/개선 피드백 루프(Evaluation & Feedback)
#   - 성능 평가, 실패 사례 분석, 정책 개선
#   - 자기 점검, 반성(reflection) 및 학습 가능성 평가
#
# 참고로 프레임워크 설계 시 중요한 점
# - 모듈성: 각 구성 요소를 독립적으로 교체/확장 가능하게 설계
# - 확장성: 새로운 도구나 도메인에 쉽게 적응 가능
# - 안전성: 권한 관리, 오류 처리, 악용 방지
# - 가시성: 추적 가능한 로그와 모니터링으로 디버깅 용이
# - 일관성: 다수의 도구를 사용할 때도 일관된 계약(입력/출력 형식)을 유지
#
# 필요하시면 위 구성 요소를 예시 아키텍처 다이어그램이나 도구 조합 예시로 더 구체화해 드릴게요.

# %% [markdown]
# ------------------------------
# 에이전트가 수행하는 과정은 다음과 같습니다:
#
# 1. **작업 분해(Task Decomposition)의 표준 방법을 검색하기 위한 쿼리를 생성합니다.**
# 2. **첫 번째 답변을 받은 후, 해당 방법의 일반적인 확장을 검색하는 두 번째 쿼리를 생성합니다.**
# 3. **필요한 모든 문맥을 확보한 후, 최종적으로 질문에 대한 답변을 생성합니다.**
